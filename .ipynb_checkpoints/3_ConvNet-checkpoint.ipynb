# %% [markdown]
# ## Convolutional Networks with TensorFlow
#
# Functions to create convolutional layers: `tf.nn.conv2d()` and `tf.nn.bias_add()`.
#
# ```
# # Output depth
# k_output = 64
#
# # Image Properties
# image_width = 10
# image_height = 10
# color_channels = 3
#
# # Convolution filter
# filter_size_width = 5
# filter_size_height = 5
#
# # Input/Image
# x = tf.placeholder(tf.float32,
#                    shape=[image_height, image_width, color_channels])
#
# # Weight and bias
# weight = tf.Variable(tf.truncated_normal(
#     [filter_size_height, filter_size_width, color_channels, k_output]))
# bias = tf.Variable(tf.zeros(k_output))
#
# # Apply Convolution
# '''
# Compute the convolution with `weight` as the filter and [1, 2, 2, 1] for the strides.
#
# TensorFlow uses a stride for each input dimension, [batch, input_height, input_width, input_channels].
# Generally always going to set the stride for batch and input_channels
# (i.e. the first and fourth element in the strides array) to be 1.
#
# The input_height and input_width strides are for striding the filter over input.
# This example code uses a stride of 2 with 5x5 filter (check convolution filter size) over input.
# '''
# conv_layer = tf.nn.conv2d(input, weight, strides=[1, 2, 2, 1], padding='SAME')
#
# # Add bias
# '''
# Adds a 1-d bias to the last dimension in a matrix.
# '''
# conv_layer = tf.nn.bias_add(conv_layer, bias)
#
# # Apply activation function
# conv_layer = tf.nn.relu(conv_layer)
#
# # Apply Max Pooling
# '''
# The ksize and strides parameters are structured as 4-element lists,
# with each element corresponding to a dimension of the input tensor ([batch, height, width, channels])
# '''
# conv_layer = tf.nn.max_pool(
#     conv_layer,
#     ksize=[1, 2, 2, 1],
#     strides=[1, 2, 2, 1],
#     padding='SAME')
# ```

# %%
import tensorflow as tf

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets(".", one_hot=True, reshape=False)

# Parameters
learning_rate = 0.00001
epochs = 10
batch_size = 128

# Samples to calculate validation and accuracy
test_valid_size = 256

# Network parameters
n_classes = 10 
dropout = 0.75


# Store layer weight and bias
weights = {'wc1': tf.Variable(tf.random_normal([5,5,1,32])),
           'wc2': tf.Variable(tf.random_normal([5,5,32,64])),
           'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
           'out': tf.Variable(tf.random_normal([1024, n_classes]))}

biases = {'bc1': tf.Variable(tf.random_normal([32])),
          'bc2': tf.Variable(tf.random_normal([64])), 
          'bd1': tf.Variable(tf.random_normal([1024])),
          'out': tf.Variable(tf.random_normal([n_classes]))}

# Convolutional layer
def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides = [1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

# Max pooling layer
def maxpool2d(x, k=2):
    return tf.nn.max_pool(x, 
                          ksize=[1,k,k,1],
                          strides=[1,k,k,1],
                          padding='SAME')
# Out:
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz

# %%
'''
MODEL:
Create 3 layers alternating between convolutions and max pooling 
followed by a fully connected and output layer. 
'''

def conv_net(x, weights, biases, keep_prob):
    # Layer 1: 28*28*1 to 14*14*32
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    conv1 = maxpool2d(conv1, k=2)
    
    # Layer 2: 14*14*32 to 7*7*64
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    conv2 = maxpool2d(conv2, k=2)
    
    # Fully connected layer: 7*7*64 to 1024
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    fc1 = tf.nn.dropout(fc1, keep_prob)
    
    # Outpur layer - class prediction: 1024 to 10
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
'''
Run the session
'''

# tf graph input
x = tf.placeholder(tf.float32, [None, 28, 28, 1])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32)

# Model
logits = conv_net(x, weights, biases, keep_prob)

# Loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(epochs):
        for batch in range(mnist.train.num_examples//batch_size):
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            sess.run(optimizer,
                     feed_dict = {x: batch_x, 
                                  y: batch_y,
                                  keep_prob: dropout})
            
            batch_loss = sess.run(loss,
                                  feed_dict = {x: batch_x,
                                               y: batch_y,
                                               keep_prob: 1.})
            
            valid_acc = sess.run(accuracy,
                                 feed_dict = {x: mnist.validation.images[:test_valid_size],
                                              y: mnist.validation.labels[:test_valid_size],
                                              keep_prob: 1.})
            
            print('Epoch {:>2}, Batch {:>3} -'
                  'Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(epoch+1,
                                                                       batch+1,
                                                                       batch_loss,
                                                                       valid_acc))
    # Calculate test accuracy
    test_acc = sess.run(accuracy,
                        feed_dict = {x: mnist.test.images[:test_valid_size],
                                     y: mnist.test.labels[:test_valid_size],
                                     keep_prob: 1.})
    print('Testing Accuracy: {}'.format(test_acc))
# Out:
# Epoch  1, Batch   1 -Loss: 105055.4375 Validation Accuracy: 0.046875
# Epoch  1, Batch   2 -Loss: 75422.3047 Validation Accuracy: 0.039062
# Epoch  1, Batch   3 -Loss: 61220.4375 Validation Accuracy: 0.039062
# Epoch  1, Batch   4 -Loss: 45164.2578 Validation Accuracy: 0.035156
# Epoch  1, Batch   5 -Loss: 37393.4844 Validation Accuracy: 0.054688
# Epoch  1, Batch   6 -Loss: 35345.2109 Validation Accuracy: 0.046875
# Epoch  1, Batch   7 -Loss: 34096.0273 Validation Accuracy: 0.074219
# Epoch  1, Batch   8 -Loss: 29982.7500 Validation Accuracy: 0.097656
# Epoch  1, Batch   9 -Loss: 28869.2793 Validation Accuracy: 0.101562
# Epoch  1, Batch  10 -Loss: 29126.3906 Validation Accuracy: 0.125000
# Epoch  1, Batch  11 -Loss: 24616.8867 Validation Accuracy: 0.140625
# Epoch  1, Batch  48 -Loss: 10069.6689 Validation Accuracy: 0.386719
# Epoch  1, Batch  49 -Loss:  9705.2725 Validation Accuracy: 0.386719
# Epoch  1, Batch  50 -Loss:  7531.1846 Validation Accuracy: 0.394531
# Epoch  1, Batch  51 -Loss:  7618.1099 Validation Accuracy: 0.398438
# Epoch  1, Batch  52 -Loss:  7697.0342 Validation Accuracy: 0.406250
# Epoch  1, Batch  53 -Loss: 10183.3486 Validation Accuracy: 0.414062
# Epoch  1, Batch  54 -Loss:  8652.7549 Validation Accuracy: 0.421875
# Epoch  1, Batch  55 -Loss:  8341.1348 Validation Accuracy: 0.429688
# Epoch  1, Batch  56 -Loss:  9739.1855 Validation Accuracy: 0.421875
# Epoch  1, Batch  57 -Loss:  8012.9521 Validation Accuracy: 0.410156
# Epoch  1, Batch  58 -Loss:  9414.5742 Validation Accuracy: 0.410156
# Epoch  1, Batch  59 -Loss:  6613.7866 Validation Accuracy: 0.425781
# Epoch  1, Batch  60 -Loss:  7883.5688 Validation Accuracy: 0.429688
# Epoch  1, Batch  61 -Loss:  7732.9434 Validation Accuracy: 0.429688
# Epoch  1, Batch  62 -Loss:  7658.3491 Validation Accuracy: 0.402344
# Epoch  1, Batch  63 -Loss:  7550.6367 Validation Accuracy: 0.406250
# Epoch  1, Batch  64 -Loss:  7959.2881 Validation Accuracy: 0.406250
# Epoch  1, Batch  65 -Loss:  8430.1455 Validation Accuracy: 0.425781
# Epoch  1, Batch  66 -Loss:  6983.6772 Validation Accuracy: 0.437500
# Epoch  1, Batch  67 -Loss:  6527.3936 Validation Accuracy: 0.437500
# Epoch  1, Batch  68 -Loss:  6685.6392 Validation Accuracy: 0.437500
# Epoch  1, Batch  69 -Loss:  7346.8574 Validation Accuracy: 0.457031
# Epoch  1, Batch  70 -Loss:  8376.3457 Validation Accuracy: 0.445312
# Epoch  1, Batch  71 -Loss:  5827.7710 Validation Accuracy: 0.464844
# Epoch  1, Batch  72 -Loss:  7282.8779 Validation Accuracy: 0.453125
# Epoch  1, Batch  73 -Loss:  4813.1631 Validation Accuracy: 0.476562
# Epoch  1, Batch  74 -Loss:  7504.7144 Validation Accuracy: 0.480469
# Epoch  1, Batch  75 -Loss:  7764.5596 Validation Accuracy: 0.464844
# Epoch  1, Batch  76 -Loss:  5030.2002 Validation Accuracy: 0.480469
# Epoch  1, Batch  77 -Loss:  6898.4009 Validation Accuracy: 0.492188
# Epoch  1, Batch  78 -Loss:  4876.2031 Validation Accuracy: 0.503906
# Epoch  1, Batch  79 -Loss:  6606.3662 Validation Accuracy: 0.496094
# Epoch  1, Batch  80 -Loss:  6644.5312 Validation Accuracy: 0.500000
# Epoch  1, Batch  81 -Loss:  5694.1216 Validation Accuracy: 0.500000
# Epoch  1, Batch  82 -Loss:  6741.5596 Validation Accuracy: 0.500000
# Epoch  1, Batch  83 -Loss:  6608.4370 Validation Accuracy: 0.511719
# Epoch  1, Batch  84 -Loss:  8006.5830 Validation Accuracy: 0.503906
# Epoch  2, Batch  24 -Loss:  1385.0977 Validation Accuracy: 0.769531
# Epoch  2, Batch  25 -Loss:  1352.0862 Validation Accuracy: 0.769531
# Epoch  2, Batch  26 -Loss:  1589.8385 Validation Accuracy: 0.769531
# Epoch  2, Batch  27 -Loss:  1705.7178 Validation Accuracy: 0.769531
# Epoch  2, Batch  28 -Loss:  1073.4988 Validation Accuracy: 0.765625
# Epoch  2, Batch  29 -Loss:  1183.7205 Validation Accuracy: 0.769531
# Epoch  2, Batch  30 -Loss:  1671.7498 Validation Accuracy: 0.765625
# Epoch  2, Batch  31 -Loss:  1222.7971 Validation Accuracy: 0.769531
# Epoch  2, Batch  32 -Loss:  1616.4067 Validation Accuracy: 0.769531
# Epoch  2, Batch  33 -Loss:  1645.7212 Validation Accuracy: 0.769531
# Epoch  2, Batch  34 -Loss:  1474.4669 Validation Accuracy: 0.769531
# Epoch  2, Batch  35 -Loss:  1135.9355 Validation Accuracy: 0.769531
# Epoch  2, Batch  36 -Loss:  2211.9209 Validation Accuracy: 0.761719
# Epoch  2, Batch  37 -Loss:  1377.2849 Validation Accuracy: 0.761719
# Epoch  2, Batch  38 -Loss:  2301.8472 Validation Accuracy: 0.765625
# Epoch  2, Batch  39 -Loss:  1443.2257 Validation Accuracy: 0.769531
# Epoch  2, Batch  40 -Loss:  1837.2336 Validation Accuracy: 0.765625
# Epoch  2, Batch  41 -Loss:  1103.4100 Validation Accuracy: 0.769531
# Epoch  2, Batch  42 -Loss:  1701.4768 Validation Accuracy: 0.761719
# Epoch  2, Batch  43 -Loss:  1538.2822 Validation Accuracy: 0.765625
# Epoch  2, Batch  44 -Loss:  1869.2954 Validation Accuracy: 0.765625
# Epoch  2, Batch  45 -Loss:  1547.9707 Validation Accuracy: 0.765625
# Epoch  2, Batch  46 -Loss:  1938.6006 Validation Accuracy: 0.777344
# Epoch  2, Batch  47 -Loss:  1530.5426 Validation Accuracy: 0.773438
# Epoch  2, Batch  48 -Loss:  1035.0959 Validation Accuracy: 0.777344
# Epoch  2, Batch  49 -Loss:  1694.3864 Validation Accuracy: 0.773438
# Epoch  2, Batch  50 -Loss:  1342.3870 Validation Accuracy: 0.773438
# Epoch  2, Batch  51 -Loss:  1210.7720 Validation Accuracy: 0.777344
# Epoch  2, Batch  52 -Loss:  1697.6915 Validation Accuracy: 0.777344
# Epoch  2, Batch  53 -Loss:  1735.4495 Validation Accuracy: 0.777344
# Epoch  2, Batch  54 -Loss:   915.0012 Validation Accuracy: 0.777344
# Epoch  2, Batch  55 -Loss:  1889.1899 Validation Accuracy: 0.781250
# Epoch  2, Batch  56 -Loss:  1430.7004 Validation Accuracy: 0.777344
# Epoch  2, Batch  57 -Loss:  1156.6643 Validation Accuracy: 0.781250
# Epoch  2, Batch  58 -Loss:  1463.3853 Validation Accuracy: 0.785156
# Epoch  2, Batch  59 -Loss:  2100.9587 Validation Accuracy: 0.777344
# Epoch  2, Batch  60 -Loss:  1656.3977 Validation Accuracy: 0.777344
# Epoch  2, Batch  61 -Loss:  1348.5455 Validation Accuracy: 0.785156
# Epoch  2, Batch  62 -Loss:  1755.0005 Validation Accuracy: 0.777344
# Epoch  2, Batch  63 -Loss:  1237.5033 Validation Accuracy: 0.777344
# Epoch  2, Batch  64 -Loss:  1587.6858 Validation Accuracy: 0.777344
# Epoch  2, Batch  65 -Loss:  1351.5754 Validation Accuracy: 0.777344
# Epoch  2, Batch  66 -Loss:  1462.1992 Validation Accuracy: 0.777344
# Epoch  2, Batch  67 -Loss:  1445.1722 Validation Accuracy: 0.777344
# Epoch  2, Batch  68 -Loss:  1776.2036 Validation Accuracy: 0.773438
# Epoch  2, Batch  69 -Loss:  1377.0538 Validation Accuracy: 0.773438
# Epoch  2, Batch  70 -Loss:  1158.3522 Validation Accuracy: 0.773438
# Epoch  2, Batch  71 -Loss:  1395.8627 Validation Accuracy: 0.777344
# Epoch  2, Batch  72 -Loss:  1796.5354 Validation Accuracy: 0.773438
# Epoch  2, Batch  73 -Loss:  1172.9713 Validation Accuracy: 0.773438
# Epoch  2, Batch  74 -Loss:  1501.9260 Validation Accuracy: 0.773438
# Epoch  2, Batch  75 -Loss:  1635.7048 Validation Accuracy: 0.777344
# Epoch  2, Batch  76 -Loss:   735.5206 Validation Accuracy: 0.777344
# Epoch  2, Batch  77 -Loss:  1510.8232 Validation Accuracy: 0.785156
# Epoch  2, Batch  78 -Loss:  1248.3279 Validation Accuracy: 0.789062
# Epoch  2, Batch  79 -Loss:  1365.1560 Validation Accuracy: 0.789062
# Epoch  2, Batch  80 -Loss:  1322.9641 Validation Accuracy: 0.800781
# Epoch  2, Batch  81 -Loss:  1163.8896 Validation Accuracy: 0.796875
# Epoch  2, Batch  82 -Loss:  1449.9434 Validation Accuracy: 0.789062
# Epoch  2, Batch  83 -Loss:  1139.4756 Validation Accuracy: 0.800781
# Epoch  2, Batch  84 -Loss:  1416.1025 Validation Accuracy: 0.789062
# Epoch  2, Batch  85 -Loss:  1480.2141 Validation Accuracy: 0.796875
# Epoch  2, Batch  86 -Loss:  1594.6771 Validation Accuracy: 0.796875
# Epoch  2, Batch  87 -Loss:  1425.5774 Validation Accuracy: 0.792969
# Epoch  2, Batch  88 -Loss:  1503.4084 Validation Accuracy: 0.796875
# Epoch  2, Batch  89 -Loss:  1156.5422 Validation Accuracy: 0.796875
# Epoch  2, Batch  90 -Loss:  1320.5061 Validation Accuracy: 0.796875
# Epoch  2, Batch  91 -Loss:  1100.3260 Validation Accuracy: 0.796875
# Epoch  2, Batch  92 -Loss:  1621.6818 Validation Accuracy: 0.792969
# Epoch  2, Batch  93 -Loss:  1762.2317 Validation Accuracy: 0.792969
# Epoch  2, Batch  94 -Loss:   865.8536 Validation Accuracy: 0.796875
# Epoch  2, Batch  95 -Loss:  1449.9353 Validation Accuracy: 0.792969
# Epoch  2, Batch  96 -Loss:  1549.6448 Validation Accuracy: 0.792969
# Epoch  2, Batch  97 -Loss:  1206.4070 Validation Accuracy: 0.796875
# Epoch 10, Batch 202 -Loss:   306.7046 Validation Accuracy: 0.863281
# Epoch 10, Batch 203 -Loss:   201.0474 Validation Accuracy: 0.863281
# Epoch 10, Batch 204 -Loss:   214.6812 Validation Accuracy: 0.863281
# Epoch 10, Batch 205 -Loss:   177.7249 Validation Accuracy: 0.863281
# Epoch 10, Batch 206 -Loss:   238.9981 Validation Accuracy: 0.863281
# Epoch 10, Batch 207 -Loss:   370.6139 Validation Accuracy: 0.867188
# Epoch 10, Batch 208 -Loss:   336.5301 Validation Accuracy: 0.863281
# Epoch 10, Batch 209 -Loss:   264.1194 Validation Accuracy: 0.867188
# Epoch 10, Batch 210 -Loss:   334.3314 Validation Accuracy: 0.871094
# Epoch 10, Batch 211 -Loss:   389.3416 Validation Accuracy: 0.871094
# Epoch 10, Batch 212 -Loss:   108.8063 Validation Accuracy: 0.871094
# Epoch 10, Batch 213 -Loss:   305.9622 Validation Accuracy: 0.867188
# Epoch 10, Batch 214 -Loss:   237.4223 Validation Accuracy: 0.867188
# Epoch 10, Batch 215 -Loss:   371.9283 Validation Accuracy: 0.867188
# Epoch 10, Batch 216 -Loss:   258.9332 Validation Accuracy: 0.867188
# Epoch 10, Batch 217 -Loss:   286.5811 Validation Accuracy: 0.863281
# Epoch 10, Batch 218 -Loss:   298.9026 Validation Accuracy: 0.863281
# Epoch 10, Batch 219 -Loss:   346.6043 Validation Accuracy: 0.859375
# Epoch 10, Batch 220 -Loss:   411.7852 Validation Accuracy: 0.863281
# Epoch 10, Batch 221 -Loss:   262.5746 Validation Accuracy: 0.859375
# Epoch 10, Batch 222 -Loss:   246.6816 Validation Accuracy: 0.859375
# Epoch 10, Batch 223 -Loss:   468.5291 Validation Accuracy: 0.863281
# Epoch 10, Batch 224 -Loss:   211.8708 Validation Accuracy: 0.863281
# Epoch 10, Batch 225 -Loss:   289.0249 Validation Accuracy: 0.863281
# Epoch 10, Batch 226 -Loss:   162.9006 Validation Accuracy: 0.859375
# Epoch 10, Batch 227 -Loss:   177.6085 Validation Accuracy: 0.859375
# Epoch 10, Batch 228 -Loss:   295.5854 Validation Accuracy: 0.859375
# Epoch 10, Batch 229 -Loss:   300.2701 Validation Accuracy: 0.859375
# Epoch 10, Batch 230 -Loss:   370.6248 Validation Accuracy: 0.863281
# Epoch 10, Batch 231 -Loss:   282.6141 Validation Accuracy: 0.863281
# Epoch 10, Batch 232 -Loss:   128.3372 Validation Accuracy: 0.863281
# Epoch 10, Batch 233 -Loss:   371.9307 Validation Accuracy: 0.867188
# Epoch 10, Batch 234 -Loss:   319.2676 Validation Accuracy: 0.867188
# Epoch 10, Batch 235 -Loss:   355.0104 Validation Accuracy: 0.863281
# Epoch 10, Batch 236 -Loss:   254.9373 Validation Accuracy: 0.867188
# Epoch 10, Batch 237 -Loss:   262.5309 Validation Accuracy: 0.867188
# Epoch 10, Batch 238 -Loss:   165.6945 Validation Accuracy: 0.867188
# Epoch 10, Batch 239 -Loss:   432.1354 Validation Accuracy: 0.867188
# Epoch 10, Batch 240 -Loss:   216.6400 Validation Accuracy: 0.867188
# Epoch 10, Batch 241 -Loss:   398.8793 Validation Accuracy: 0.867188
# Epoch 10, Batch 242 -Loss:   399.1378 Validation Accuracy: 0.867188
# Epoch 10, Batch 243 -Loss:   312.7482 Validation Accuracy: 0.867188
# Epoch 10, Batch 244 -Loss:   143.5738 Validation Accuracy: 0.867188
# Epoch 10, Batch 245 -Loss:   391.6116 Validation Accuracy: 0.867188
# Epoch 10, Batch 246 -Loss:   225.8653 Validation Accuracy: 0.867188
# Epoch 10, Batch 247 -Loss:   333.0502 Validation Accuracy: 0.867188
# Epoch 10, Batch 248 -Loss:   381.0045 Validation Accuracy: 0.867188
# Epoch 10, Batch 249 -Loss:   199.1056 Validation Accuracy: 0.867188
# Epoch 10, Batch 250 -Loss:   169.0594 Validation Accuracy: 0.867188
# Epoch 10, Batch 251 -Loss:   213.6295 Validation Accuracy: 0.867188
# Epoch 10, Batch 252 -Loss:   151.6938 Validation Accuracy: 0.863281
# Epoch 10, Batch 253 -Loss:   279.7796 Validation Accuracy: 0.863281
# Epoch 10, Batch 254 -Loss:   208.7212 Validation Accuracy: 0.863281
# Epoch 10, Batch 255 -Loss:   202.7513 Validation Accuracy: 0.863281
# Epoch 10, Batch 256 -Loss:   164.7234 Validation Accuracy: 0.863281
# Epoch 10, Batch 257 -Loss:   205.7981 Validation Accuracy: 0.863281
# Epoch 10, Batch 258 -Loss:   166.4414 Validation Accuracy: 0.863281
# Epoch 10, Batch 259 -Loss:   219.5394 Validation Accuracy: 0.863281
# Epoch 10, Batch 260 -Loss:   258.4389 Validation Accuracy: 0.863281
# Epoch 10, Batch 261 -Loss:   411.8406 Validation Accuracy: 0.863281
# Epoch 10, Batch 262 -Loss:   394.5107 Validation Accuracy: 0.867188
# Epoch 10, Batch 263 -Loss:   287.0050 Validation Accuracy: 0.871094
# Epoch 10, Batch 264 -Loss:   336.3853 Validation Accuracy: 0.871094
# Epoch 10, Batch 265 -Loss:   201.4771 Validation Accuracy: 0.871094
# Epoch 10, Batch 266 -Loss:   241.1254 Validation Accuracy: 0.867188
# Epoch 10, Batch 267 -Loss:   434.5480 Validation Accuracy: 0.871094
# Epoch 10, Batch 268 -Loss:   442.3990 Validation Accuracy: 0.867188
# Epoch 10, Batch 269 -Loss:   449.1564 Validation Accuracy: 0.867188
# Epoch 10, Batch 270 -Loss:   290.1249 Validation Accuracy: 0.867188
# Epoch 10, Batch 271 -Loss:   349.0170 Validation Accuracy: 0.867188
# Epoch 10, Batch 272 -Loss:   428.4987 Validation Accuracy: 0.867188
# Epoch 10, Batch 273 -Loss:   189.6412 Validation Accuracy: 0.867188
# Epoch 10, Batch 274 -Loss:   413.8048 Validation Accuracy: 0.867188
# Epoch 10, Batch 275 -Loss:   242.9345 Validation Accuracy: 0.867188
# Epoch 10, Batch 276 -Loss:   296.9387 Validation Accuracy: 0.867188
# Epoch 10, Batch 428 -Loss:   330.5903 Validation Accuracy: 0.859375
# Epoch 10, Batch 429 -Loss:   355.1761 Validation Accuracy: 0.859375
# Testing Accuracy: 0.8515625

# %% [markdown]
# ### Convolution filters, weights, and biases dimension set up
#
# Setup the `strides`, `padding` and filter weight/bias (`F_w` and `F_b`) such that the output shape is (1, 2, 2, 3). Note that all of these except `strides` should be TensorFlow variables.
#
# To determine the size of the filter:
#
# `new_height = (input_height - filter_height + 2 * P)/S + 1`
#
# `new_width = (input_width - filter_width + 2 * P)/S + 1`
#
# OR
#
# ```
# out_height = ceil(float(in_height - filter_height + 1) / float(strides[1]))
# out_width  = ceil(float(in_width - filter_width + 1) / float(strides[2]))
# ```

# %%
"""
Setup the strides, padding and filter weight/bias such that
the output shape is (1, 2, 2, 3).
FROM SOLUTION
"""
import tensorflow as tf
import numpy as np

# `tf.nn.conv2d` requires the input be 4D (batch_size, height, width, depth)
# (1, 4, 4, 1)
x = np.array([
    [0, 1, 0.5, 10],
    [2, 2.5, 1, -8],
    [4, 0, 5, 6],
    [15, 1, 2, 3]], dtype=np.float32).reshape((1, 4, 4, 1))
X = tf.constant(x)


def conv2d(input):
    # Filter (weights and bias)
    # The shape of the filter weight is (height, width, input_depth, output_depth)
    # The shape of the filter bias is (output_depth,)
    # TODO: Define the filter weights `F_W` and filter bias `F_b`.
    # NOTE: Remember to wrap them in `tf.Variable`, they are trainable parameters after all.
    F_W = tf.Variable(tf.truncated_normal((2, 2, 1, 3)))
    F_b = tf.Variable(tf.zeros(3))
    # TODO: Set the stride for each dimension (batch_size, height, width, depth)
    strides = [1, 2, 2, 1]
    # TODO: set the padding, either 'VALID' or 'SAME'.
    padding = 'VALID'
    # https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#conv2d
    # `tf.nn.conv2d` does not include the bias computation so we have to add it ourselves after.
    return tf.nn.conv2d(input, F_W, strides, padding) + F_b

out = conv2d(X)
print(out.get_shape())
# Out:
# (1, 2, 2, 3)

# %% [markdown]
# ### Pooling

# %%
"""
Set the values to `strides` and `ksize` such that
the output shape after pooling is (1, 2, 2, 1).
"""
import tensorflow as tf
import numpy as np

# `tf.nn.max_pool` requires the input be 4D (batch_size, height, width, depth)
# (1, 4, 4, 1)
x = np.array([
    [0, 1, 0.5, 10],
    [2, 2.5, 1, -8],
    [4, 0, 5, 6],
    [15, 1, 2, 3]], dtype=np.float32).reshape((1, 4, 4, 1))
X = tf.constant(x)

def maxpool(input):
    # TODO: Set the ksize (filter size) for each dimension (batch_size, height, width, depth)
    ksize = [1, 2, 2, 1]
    # TODO: Set the stride for each dimension (batch_size, height, width, depth)
    strides = [1, 2, 2, 1]
    # TODO: set the padding, either 'VALID' or 'SAME'.
    padding = 'SAME'
    # https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#max_pool
    return tf.nn.max_pool(input, ksize, strides, padding)
    
out = maxpool(X)

print(out.get_shape())
# Out:
# (1, 2, 2, 1)
